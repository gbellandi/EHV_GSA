# %%
from __future__ import print_function, division # Python 3 printing and division

import pandas as pd
import numpy as np
import seaborn as sns
import os, shutil, glob

# from sklearn.utils.extmath import cartesian
import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
# import matplotlib.ticker as plticker
# from matplotlib.backends.backend_pdf import PdfPages
# import matplotlib.cm as cm
# import matplotlib.mlab as mlab
# from matplotlib.mlab import griddata
# %matplotlib inline

# %%
from SALib.sample import saltelli, latin
from SALib.analyze import sobol, delta
from SALib.test_functions import Ishigami

import pystran

# %%
def reshape_files(case_dir,case_name,sim_type,num_scenarios):
    """
    Takes in WEST output files (Steady State.out.txt or Dynamic.out.txt) in a directory (case_dir),
    reads them and arranges them per output variable (instead of per scenario) in a dictionary
    """
    #Initialise everything by reading first file 
    file_name = '%04d'%0 + '_' + case_name + '.' + sim_type + '.' + 'Simul.out.txt'
    output = pd.read_csv(os.path.join(case_dir, file_name), sep='\t')
    result_dict = {k: pd.DataFrame() for k in output.columns}
    result_units = {tag: unit for tag,unit in zip(output.columns,output.loc[0])}
    
    for var_name in result_dict.keys():
        result_dict[var_name]['scen'+'%d'%0] = output[var_name][-100:].astype(float)
    
    #Loop over the rest of the files, once per file and once per output variable
    for i in range(1,num_scenarios):
        file_name = '%04d'%i + '_' + case_name + '.' + sim_type + '.' + 'Simul.out.txt'
        output = pd.read_csv(os.path.join(case_dir, file_name), sep='\t')
        for var_name in result_dict.keys():
            previous_data = result_dict[var_name]
            new_data = pd.DataFrame({'scen'+'%d'%i : output[var_name][-100:].astype(float)})
            result_dict[var_name] = pd.concat([previous_data,new_data],axis=1)
    
    return result_dict, result_units

def run_GSA(scenario, case_dir, case_name, save_dir, experiment_type, timeout_duration):
    scen_id = scenario[0]
    parameter_dict = scenario[1]
    #parameter_dict=dict(zip(parsets2run.columns.values,values))

    scen = py2WEST.WestWrapper(case_dir, case_name, save_dir, scen_id, parameter_dict,
                               experiment_type=experiment_type, timeout=timeout_duration)
    scen.run_west()
    
    #include reshape files function here, so this function is also executed on cluster
    return [scen_id, scen.succes]

# %% [markdown]
# # py2west section

# %% [markdown]
# <font size=3> <b> use this for running a simulation on the eraser and then analize the results in the next sections

# %%
from __future__ import print_function, division # Python 3 printing and division

import pandas as pd
import numpy as np
import seaborn as sns
import os, shutil, glob
import py2WEST

from sklearn.utils.extmath import cartesian
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.ticker as plticker
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm
import matplotlib.mlab as mlab
from matplotlib.mlab import griddata
# %matplotlib inline

# %%
import ipyparallel as ipp
c = ipp.Client()

# %%
# %%px --local
# import subprocess                           # Run commands in bash
# import signal                               # Needed to limit calculation time per simulation
# import shutil
# import xml.etree.ElementTree as etxml
# import lxml
# import os
# import py2WEST                              # imported as py2WEST; parse_xml file is saved in py2WEST folder as a package
# import dill
# import pickle
# from ipykernel import serialize
# serialize.pickle = pickle

# %%
dview = c[:]                                    # Make directView of all clients, used to parse data/objects to cores
lview = c.load_balanced_view()             # Make balancedView of all clients, used for dynamic calculations

# %%
pywest_dir = './'
case_dir = '/home/data/gbelland/gitRepos/EHV_GSA/WEST16_DRYW_N2O/'
save_dir = '/home/data/gbelland/gitRepos/EHV_GSA/WEST16_DRYW_N2O/'

# %%
case_name = 'Eindhoven'
experiment_type = r"steady state"#r"dynamic"#
timeout_duration = 2000 #s
default_output = None

# %% [markdown]
# <font size=3> <b> N.B.: for global parameters insert the parameter name without point before it

# %% [markdown]
# ## pySTrAn sampling

# %%
Xi = [(0.06, 1.74, 'K_O_A1Lysis'), (0.151, 0.739, 'K_O_A2Lysis'), (0.0028, 0.3052, 'b_A1'),
      (0.0028, 0.3052, 'b_A2'), (0.001, 0.8, 'n_NOx_A1_d'), (0.0006, 0.0054, 'K_FA'), (0.00000005, 0.000545, 'K_FNA'),
      (0.45, 1.05, 'K_I10FA'), (0.01, 0.2, 'K_I10FNA'), (0.01, 1.09, 'K_I9FA'), (0.001, 0.1009, 'K_I9FNA'), 
      (0.38, 0.62, 'K_OA1'), (0.98, 1.22, 'K_OA2'), (0.14, 0.25, 'Y_A1'), (0.042,  0.258, 'Y_A2'), 
      (0.0009, 1.1, 'K_FA_AOBden'), (0.0000005, 0.003, 'K_FNA_AOBden'), (0.01, 11, 'K_IO_AOBden'),
      (0.08, 4.3, 'K_SNO_AOBden'), (0.01, 13.2, 'K_SO_AOBden'), (0.025, 0.685, 'n1_AOB'), (0.025, 0.685, 'n2_AOB'),
      (2.4, 21.6, 'K_A1'), (2.4, 21.6, 'K_F1'), (0.12, 1.08, 'K_O1_BH')]

# Xi = [(0.01, 11, 'K_IO_AOBden'), (0.08, 4.3, 'K_SNO_AOBden'), (0.01, 13.2, 'K_SO_AOBden')]    

#prepare model class
goat=pystran.GlobalOATSensitivity(Xi)

#prepare the parameter sample
goat.PrepareSample(100, 0.001, samplemethod='lh', numerical_approach='central')
columns=[]

for i in Xi:
    columns=np.append(columns, i[2]).tolist()
param_values = goat.parset2run
# Out:
# The analysed model is externally run

# %% [markdown]
# ## simulate with py2WEST

# %%
param_values.shape
# Out:
# (5000, 25)

# %%
parasets = pd.DataFrame(param_values, columns=columns)

# %%
scenario = []
for row in parasets.index:
    scenario.append([row, py2WEST.parse_xml.dframe_to_dict(parasets, row)])
scenario_len = len(scenario)
scenario
# Out:
# [[0,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6897750587051077,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [1,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6863988847616411,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [2,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36968248673477161,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [3,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.3689438603876492,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [4,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17020585336371885,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [5,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.16986578172862649,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [6,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17885266773840908,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [7,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17849531975091976,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [8,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.504450524730789}],
#  [9,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50344263157448366}],
#  [10,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039226649388520215,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [11,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039148274464667031,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [12,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.00020353230557892753,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [13,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.00020312564762572287,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [14,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61556654002159827,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [15,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61433663684473194,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [16,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078980610459049208,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [17,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078822807041548607,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [18,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89128199163994637,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [19,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.88950120843986658,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [20,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.085896567220875381,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [21,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.085724945707946559,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [22,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44937481495538256,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [23,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44847696317724994,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [24,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1255773377848837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [25,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1233284320150838,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [26,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.15717878137509408,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [27,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.15686473785586311,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [28,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19128409336987073,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [29,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19090190736913171,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [30,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0273989485356647,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [31,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0253462033837455,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [32,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013049136534954084,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [33,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013023064334085044,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [34,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7546515338765758,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [35,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7411557266160838,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [36,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9892622226458991,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [37,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9812916687544986,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [38,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.208414431428411,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [39,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.184021995001979,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [40,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17997358666400257,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [41,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17961399907826028,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [42,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41864466361232111,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [43,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41780821073797081,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [44,
#   {'K_A1': 9.8523244847107261,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [45,
#   {'K_A1': 9.8326395207053086,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [46,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.065957228941327,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [47,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.045845426286101,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.4632142282332995,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [48,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.46367744246153281,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [49,
#   {'K_A1': 9.8424820027080173,
#    'K_F1': 10.055901327613714,
#    'K_FA': 0.0039187461926593623,
#    'K_FA_AOBden': 1.0263725759597051,
#    'K_FNA': 0.0002033289766023252,
#    'K_FNA_AOBden': 0.0013036100434519564,
#    'K_I10FA': 0.61495158843316511,
#    'K_I10FNA': 0.078901708750298907,
#    'K_I9FA': 0.89039160003990647,
#    'K_I9FNA': 0.08581075646441097,
#    'K_IO_AOBden': 6.7479036302463298,
#    'K_O1_BH': 0.46275101400506619,
#    'K_OA1': 0.44892588906631625,
#    'K_OA2': 1.1244528848999837,
#    'K_O_A1Lysis': 1.6880869717333744,
#    'K_O_A2Lysis': 0.36931317356121041,
#    'K_SNO_AOBden': 3.9852769457001989,
#    'K_SO_AOBden': 12.196218213215195,
#    'Y_A1': 0.1570217596154786,
#    'Y_A2': 0.19109300036950122,
#    'b_A1': 0.17003581754617267,
#    'b_A2': 0.17867399374466442,
#    'n1_AOB': 0.17979379287113142,
#    'n2_AOB': 0.41822643717514596,
#    'n_NOx_A1_d': 0.50394657815263633}],
#  [50,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85566449229979835,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [51,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85395487293456396,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [52,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.65191488124933228,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [53,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.65061235401406892,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [54,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
# ...
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027923454051520359,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [83,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027867662934534304,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [84,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.6853061893949732,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [85,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.6799409422633147,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [86,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6714505538900342,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [87,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6681109923438002,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [88,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17233367380858158,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [89,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.171989350783989,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [90,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40400186228385737,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [91,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40319466575581775,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [92,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.08550219662243784,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [93,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085331363062752644,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [94,
#   {'K_A1': 20.709647195416277,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [95,
#   {'K_A1': 20.668269278941917,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [96,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.608369967979563,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [97,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.583178419591992,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0087879517715486,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [98,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0097967397233201,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}],
#  [99,
#   {'K_A1': 20.688958237179097,
#    'K_F1': 12.595774193785777,
#    'K_FA': 0.00082769946054634367,
#    'K_FA_AOBden': 0.44712425450427534,
#    'K_FNA': 0.00048730109811964727,
#    'K_FNA_AOBden': 0.0027895558493027332,
#    'K_I10FA': 0.92304041851255747,
#    'K_I10FNA': 0.16151502465302225,
#    'K_I9FA': 0.05705706939114772,
#    'K_I9FNA': 0.0093552541203426286,
#    'K_IO_AOBden': 2.682623565829144,
#    'K_O1_BH': 1.0077791638197771,
#    'K_OA1': 0.58599641039839134,
#    'K_OA2': 1.0339322232922936,
#    'K_O_A1Lysis': 0.85480968261718115,
#    'K_O_A2Lysis': 0.6512636176317006,
#    'K_SNO_AOBden': 1.6697807731169172,
#    'K_SO_AOBden': 0.17216151229628529,
#    'Y_A1': 0.19698295830532925,
#    'Y_A2': 0.081653395293866948,
#    'b_A1': 0.093223150782595077,
#    'b_A2': 0.053341434789197416,
#    'n1_AOB': 0.40359826401983756,
#    'n2_AOB': 0.085416779842595242,
#    'n_NOx_A1_d': 0.27665909937795391}]]

# %%
out = lview.map_async(run_GSA, scenario, [case_dir]*scenario_len, [case_name]*scenario_len, [save_dir]*scenario_len,
                      [experiment_type]*scenario_len, [timeout_duration]*scenario_len)
#while out.progress != scenario_len:
#    continue
print('Done!')
# Out:
# Done!

# %%
out.progress
# Out:
# 100

# %%
#Lijst [scenario_id, success (1) or no succes (0)]
success = [row[1] for row in out.result()]
failed_scenarios = [i for i,x in enumerate(success) if x == 0]
print(failed_scenarios)
if len(failed_scenarios) != 0:
    print("Total of:", len(failed_scenarios))
# Out:
# []

# %% [raw]
# # move output files from the case folder to another folder (NOTE: temporary solution to the py2WEST save_dir variable which is not yet active)
# for txt_file in glob.iglob('/home/data/gbelland/gitRepos/WEST16_DRYW_N2O/*out.txt'):
#     shutil.move(txt_file, '/home/data/gbelland/gitRepos/WEST16_DRYW_N2O/py2WoutputSS/')

# %% [markdown]
# # show results and analysis with pystran

# %% [markdown]
# ## check model outputs

# %%
results, units = reshape_files('./results/ranking/10runs_10e_3pert/',
                               'Eindhoven', 'Steady State', goat.parset2run.shape[0]) # or Dynamic!
# for key in units.keys():
#     fig, ax = plt.subplots()
#     for column in results['#.t'].columns:
#         ax.plot(results['#.t'][column],results[key][column],label=column)
#         ax.set_title(key,fontsize=14)
#         ax.legend(results['#.t'].columns)

# %% [markdown]
# pd.to_pickle(scenario, './results/scenario')
# pd.to_pickle(results, './results/results')

# %% [markdown]
# scenario = pd.read_pickled('./results/scenario')

# %% [markdown]
# ### ranking 10 samples and 1e-6 perturbation

# %%
results['.Aer_Anox_ZP.C(S_N2O)'].shape
# Out:
# (100, 500)

# %%
#evaluate sensitivity
goat.Calc_sensitivity(np.array(results['.Aer_Anox_ZP.C(S_N2O)'].values).T)
#transform sensitivity into ranking
goat.Get_ranking() 

#plot the partial effect based sensitivity
fig, ax1 = goat.plotsens(indice='PE', ec='grey',fc='grey', outputid=10)
fig.set_size_inches(20, 10)
ax1.set_xticklabels(parasets.columns, rotation=90);
# plt.savefig('n2o_ranking_10runs_10e_6pert.png', dpi=300, bbox_inches='tight')
# Out:
# Use PE_SENS for ranking purposes; since it uses the absolute value of the change; giving no compensation between positive and negative partial effects
# Combined ranking, by taking minimum ranking of the parameters over the different outputs
# K_O_A1Lysis  :  4
# K_O_A2Lysis  :  7
# b_A1  :  1
# b_A2  :  3
# n_NOx_A1_d  :  5
# K_FA  :  3
# K_FNA  :  4
# K_I10FA  :  10
# K_I10FNA  :  10
# K_I9FA  :  3
# K_I9FNA  :  9
# K_OA1  :  2
# K_OA2  :  2
# Y_A1  :  3
# Y_A2  :  10
# K_FA_AOBden  :  13
# K_FNA_AOBden  :  10
# K_IO_AOBden  :  12
# K_SNO_AOBden  :  11
# K_SO_AOBden  :  8
# n1_AOB  :  8
# n2_AOB  :  8
# K_A1  :  9
# K_F1  :  4
# K_O1_BH  :  5

# %%
#evaluate sensitivity
goat.Calc_sensitivity(np.array(results['.Aer_Anox_ZP.C(S_NO3)'].values).T)
#transform sensitivity into ranking
goat.Get_ranking() 

#plot the partial effect based sensitivity
fig, ax1 = goat.plotsens(indice='PE', ec='grey',fc='grey', outputid=10)
fig.set_size_inches(20, 10)
ax1.set_xticklabels(parasets.columns, rotation=90);
# plt.savefig('no3_ranking_10runs_10e_6pert.png', dpi=300, bbox_inches='tight')
# Out:
# Use PE_SENS for ranking purposes; since it uses the absolute value of the change; giving no compensation between positive and negative partial effects
# Combined ranking, by taking minimum ranking of the parameters over the different outputs
# K_O_A1Lysis  :  7
# K_O_A2Lysis  :  5
# b_A1  :  1
# b_A2  :  1
# n_NOx_A1_d  :  6
# K_FA  :  6
# K_FNA  :  4
# K_I10FA  :  9
# K_I10FNA  :  11
# K_I9FA  :  6
# K_I9FNA  :  12
# K_OA1  :  4
# K_OA2  :  1
# Y_A1  :  5
# Y_A2  :  5
# K_FA_AOBden  :  14
# K_FNA_AOBden  :  12
# K_IO_AOBden  :  17
# K_SNO_AOBden  :  14
# K_SO_AOBden  :  12
# n1_AOB  :  12
# n2_AOB  :  13
# K_A1  :  11
# K_F1  :  7
# K_O1_BH  :  10

# %%
#evaluate sensitivity
goat.Calc_sensitivity(np.array(results['.Aer_Anox_ZP.C(S_O)'].values).T)
#transform sensitivity into ranking
goat.Get_ranking() 

#plot the partial effect based sensitivity
fig, ax1 = goat.plotsens(indice='PE', ec='grey',fc='grey', outputid=10)
fig.set_size_inches(20, 10)
ax1.set_xticklabels(parasets.columns, rotation=90);
# plt.savefig('DO_ranking_10runs_10e_6pert.png', dpi=300, bbox_inches='tight')
# Out:
# Use PE_SENS for ranking purposes; since it uses the absolute value of the change; giving no compensation between positive and negative partial effects
# Combined ranking, by taking minimum ranking of the parameters over the different outputs
# K_O_A1Lysis  :  2
# K_O_A2Lysis  :  3
# b_A1  :  1
# b_A2  :  2
# n_NOx_A1_d  :  2
# K_FA  :  2
# K_FNA  :  3
# K_I10FA  :  9
# K_I10FNA  :  17
# K_I9FA  :  2
# K_I9FNA  :  6
# K_OA1  :  1
# K_OA2  :  1
# Y_A1  :  1
# Y_A2  :  3
# K_FA_AOBden  :  10
# K_FNA_AOBden  :  9
# K_IO_AOBden  :  8
# K_SNO_AOBden  :  7
# K_SO_AOBden  :  6
# n1_AOB  :  5
# n2_AOB  :  4
# K_A1  :  3
# K_F1  :  2
# K_O1_BH  :  3

# %%
#evaluate sensitivity
goat.Calc_sensitivity(np.array(results['.Aer_Anox_ZP.C(X_BA1)'].values).T)
#transform sensitivity into ranking
goat.Get_ranking() 

#plot the partial effect based sensitivity
fig, ax1 = goat.plotsens(indice='PE', ec='grey',fc='grey', outputid=10)
fig.set_size_inches(20, 10)
ax1.set_xticklabels(parasets.columns, rotation=90);
# plt.savefig('X_BA1_ranking_10runs_10e_6pert.png', dpi=300, bbox_inches='tight')
# Out:
# Use PE_SENS for ranking purposes; since it uses the absolute value of the change; giving no compensation between positive and negative partial effects
# Combined ranking, by taking minimum ranking of the parameters over the different outputs
# K_O_A1Lysis  :  3
# K_O_A2Lysis  :  14
# b_A1  :  1
# b_A2  :  5
# n_NOx_A1_d  :  3
# K_FA  :  4
# K_FNA  :  6
# K_I10FA  :  9
# K_I10FNA  :  9
# K_I9FA  :  4
# K_I9FNA  :  7
# K_OA1  :  2
# K_OA2  :  4
# Y_A1  :  1
# Y_A2  :  7
# K_FA_AOBden  :  10
# K_FNA_AOBden  :  9
# K_IO_AOBden  :  11
# K_SNO_AOBden  :  10
# K_SO_AOBden  :  7
# n1_AOB  :  7
# n2_AOB  :  7
# K_A1  :  6
# K_F1  :  6
# K_O1_BH  :  8

# %%
#evaluate sensitivity
goat.Calc_sensitivity(np.array(results['.Aer_Anox_ZP.C(X_BA2)'].values).T)
#transform sensitivity into ranking
goat.Get_ranking() 

#plot the partial effect based sensitivity
fig, ax1 = goat.plotsens(indice='PE', ec='grey',fc='grey', outputid=10)
fig.set_size_inches(20, 10)
ax1.set_xticklabels(parasets.columns, rotation=90);
# plt.savefig('X_BA2_ranking_10runs_10e_6pert.png', dpi=300, bbox_inches='tight')
# Out:
# Use PE_SENS for ranking purposes; since it uses the absolute value of the change; giving no compensation between positive and negative partial effects
# Combined ranking, by taking minimum ranking of the parameters over the different outputs
# K_O_A1Lysis  :  7
# K_O_A2Lysis  :  5
# b_A1  :  2
# b_A2  :  1
# n_NOx_A1_d  :  7
# K_FA  :  6
# K_FNA  :  4
# K_I10FA  :  11
# K_I10FNA  :  9
# K_I9FA  :  6
# K_I9FNA  :  12
# K_OA1  :  4
# K_OA2  :  1
# Y_A1  :  5
# Y_A2  :  5
# K_FA_AOBden  :  16
# K_FNA_AOBden  :  12
# K_IO_AOBden  :  18
# K_SNO_AOBden  :  17
# K_SO_AOBden  :  16
# n1_AOB  :  14
# n2_AOB  :  14
# K_A1  :  13
# K_F1  :  8
# K_O1_BH  :  9

# %%
#evaluate sensitivity
goat.Calc_sensitivity(np.array(results['.Aer_Anox_ZP.C(X_H)']).T)
#transform sensitivity into ranking
goat.Get_ranking() 

#plot the partial effect based sensitivity
fig, ax1 = goat.plotsens(indice='PE', ec='grey',fc='grey', outputid=10)
fig.set_size_inches(20, 10)
ax1.set_xticklabels(parasets.columns, rotation=90);
# plt.savefig('X_H_ranking_10runs_10e_6pert.png', dpi=300, bbox_inches='tight')
# Out:
# Use PE_SENS for ranking purposes; since it uses the absolute value of the change; giving no compensation between positive and negative partial effects
# Combined ranking, by taking minimum ranking of the parameters over the different outputs
# K_O_A1Lysis  :  1
# K_O_A2Lysis  :  7
# b_A1  :  1
# b_A2  :  1
# n_NOx_A1_d  :  5
# K_FA  :  4
# K_FNA  :  3
# K_I10FA  :  8
# K_I10FNA  :  12
# K_I9FA  :  3
# K_I9FNA  :  7
# K_OA1  :  2
# K_OA2  :  1
# Y_A1  :  2
# Y_A2  :  5
# K_FA_AOBden  :  9
# K_FNA_AOBden  :  8
# K_IO_AOBden  :  7
# K_SNO_AOBden  :  6
# K_SO_AOBden  :  5
# n1_AOB  :  4
# n2_AOB  :  3
# K_A1  :  2
# K_F1  :  1
# K_O1_BH  :  1

# %%
#evaluate sensitivity
goat.Calc_sensitivity(np.array(results['.Aer_Anox_ZP.C(X_TSS)'].values).T)
#transform sensitivity into ranking
goat.Get_ranking() 

#plot the partial effect based sensitivity
fig, ax1 = goat.plotsens(indice='PE', ec='grey',fc='grey', outputid=10)
fig.set_size_inches(20, 10)
ax1.set_xticklabels(parasets.columns, rotation=90);
# plt.savefig('TSS_ranking_10runs_10e_6pert.png', dpi=300, bbox_inches='tight')
# Out:
# Use PE_SENS for ranking purposes; since it uses the absolute value of the change; giving no compensation between positive and negative partial effects
# Combined ranking, by taking minimum ranking of the parameters over the different outputs
# K_O_A1Lysis  :  1
# K_O_A2Lysis  :  12
# b_A1  :  1
# b_A2  :  1
# n_NOx_A1_d  :  9
# K_FA  :  8
# K_FNA  :  3
# K_I10FA  :  17
# K_I10FNA  :  16
# K_I9FA  :  15
# K_I9FNA  :  14
# K_OA1  :  4
# K_OA2  :  1
# Y_A1  :  1
# Y_A2  :  2
# K_FA_AOBden  :  9
# K_FNA_AOBden  :  8
# K_IO_AOBden  :  7
# K_SNO_AOBden  :  6
# K_SO_AOBden  :  5
# n1_AOB  :  4
# n2_AOB  :  3
# K_A1  :  2
# K_F1  :  2
# K_O1_BH  :  5

# %% [markdown]
# ### ranking 10 samples and 1e-3 perturbation

# %% [markdown]
# <font size=4> in this section we check whether there is an important effect of perturbation size on the par ranking. <p\>
# - If so: new simulations with dedicated perturbation factos for each par
# - in any case, then increase number of simulations

# %%
results['.Aer_Anox_ZP.C(S_N2O)'].shape
# Out:
# (100, 500)

# %%
#evaluate sensitivity
goat.Calc_sensitivity(np.array(results['.Aer_Anox_ZP.C(S_N2O)'].values).T)
#transform sensitivity into ranking
goat.Get_ranking() 

#plot the partial effect based sensitivity
fig, ax1 = goat.plotsens(indice='PE', ec='grey',fc='grey', outputid=10)
fig.set_size_inches(20, 10)
ax1.set_xticklabels(parasets.columns, rotation=90);
plt.savefig('n2o_ranking_10runs_10e_3pert.png', dpi=300, bbox_inches='tight')
# Out:
# Use PE_SENS for ranking purposes; since it uses the absolute value of the change; giving no compensation between positive and negative partial effects
# Combined ranking, by taking minimum ranking of the parameters over the different outputs
# K_O_A1Lysis  :  9
# K_O_A2Lysis  :  12
# b_A1  :  1
# b_A2  :  3
# n_NOx_A1_d  :  6
# K_FA  :  7
# K_FNA  :  5
# K_I10FA  :  15
# K_I10FNA  :  19
# K_I9FA  :  7
# K_I9FNA  :  16
# K_OA1  :  4
# K_OA2  :  2
# Y_A1  :  11
# Y_A2  :  14
# K_FA_AOBden  :  16
# K_FNA_AOBden  :  19
# K_IO_AOBden  :  22
# K_SNO_AOBden  :  24
# K_SO_AOBden  :  21
# n1_AOB  :  16
# n2_AOB  :  24
# K_A1  :  23
# K_F1  :  10
# K_O1_BH  :  13

# %%
#evaluate sensitivity
goat.Calc_sensitivity(np.array(results['.Aer_Anox_ZP.C(S_NO3)'].values).T)
#transform sensitivity into ranking
goat.Get_ranking() 

#plot the partial effect based sensitivity
fig, ax1 = goat.plotsens(indice='PE', ec='grey',fc='grey', outputid=10)
fig.set_size_inches(20, 10)
ax1.set_xticklabels(parasets.columns, rotation=90);
plt.savefig('no3_ranking_10runs_10e_3pert.png', dpi=300, bbox_inches='tight')
# Out:
# Use PE_SENS for ranking purposes; since it uses the absolute value of the change; giving no compensation between positive and negative partial effects
# Combined ranking, by taking minimum ranking of the parameters over the different outputs
# K_O_A1Lysis  :  12
# K_O_A2Lysis  :  9
# b_A1  :  3
# b_A2  :  2
# n_NOx_A1_d  :  7
# K_FA  :  10
# K_FNA  :  4
# K_I10FA  :  15
# K_I10FNA  :  17
# K_I9FA  :  11
# K_I9FNA  :  16
# K_OA1  :  5
# K_OA2  :  1
# Y_A1  :  6
# Y_A2  :  8
# K_FA_AOBden  :  18
# K_FNA_AOBden  :  21
# K_IO_AOBden  :  23
# K_SNO_AOBden  :  24
# K_SO_AOBden  :  21
# n1_AOB  :  18
# n2_AOB  :  24
# K_A1  :  18
# K_F1  :  13
# K_O1_BH  :  14

# %%
#evaluate sensitivity
goat.Calc_sensitivity(np.array(results['.Aer_Anox_ZP.C(S_O)'].values).T)
#transform sensitivity into ranking
goat.Get_ranking() 

#plot the partial effect based sensitivity
fig, ax1 = goat.plotsens(indice='PE', ec='grey',fc='grey', outputid=10)
fig.set_size_inches(20, 10)
ax1.set_xticklabels(parasets.columns, rotation=90);
plt.savefig('DO_ranking_10runs_10e_3pert.png', dpi=300, bbox_inches='tight')
# Out:
# Use PE_SENS for ranking purposes; since it uses the absolute value of the change; giving no compensation between positive and negative partial effects
# Combined ranking, by taking minimum ranking of the parameters over the different outputs
# K_O_A1Lysis  :  9
# K_O_A2Lysis  :  15
# b_A1  :  1
# b_A2  :  8
# n_NOx_A1_d  :  3
# K_FA  :  4
# K_FNA  :  11
# K_I10FA  :  16
# K_I10FNA  :  17
# K_I9FA  :  6
# K_I9FNA  :  13
# K_OA1  :  2
# K_OA2  :  5
# Y_A1  :  7
# Y_A2  :  13
# K_FA_AOBden  :  17
# K_FNA_AOBden  :  18
# K_IO_AOBden  :  22
# K_SNO_AOBden  :  23
# K_SO_AOBden  :  20
# n1_AOB  :  17
# n2_AOB  :  24
# K_A1  :  17
# K_F1  :  10
# K_O1_BH  :  12

# %%
#evaluate sensitivity
goat.Calc_sensitivity(np.array(results['.Aer_Anox_ZP.C(X_BA1)'].values).T)
#transform sensitivity into ranking
goat.Get_ranking() 

#plot the partial effect based sensitivity
fig, ax1 = goat.plotsens(indice='PE', ec='grey',fc='grey', outputid=10)
fig.set_size_inches(20, 10)
ax1.set_xticklabels(parasets.columns, rotation=90);
plt.savefig('X_BA1_ranking_10runs_10e_3pert.png', dpi=300, bbox_inches='tight')
# Out:
# Use PE_SENS for ranking purposes; since it uses the absolute value of the change; giving no compensation between positive and negative partial effects
# Combined ranking, by taking minimum ranking of the parameters over the different outputs
# K_O_A1Lysis  :  6
# K_O_A2Lysis  :  15
# b_A1  :  1
# b_A2  :  9
# n_NOx_A1_d  :  3
# K_FA  :  7
# K_FNA  :  10
# K_I10FA  :  16
# K_I10FNA  :  20
# K_I9FA  :  5
# K_I9FNA  :  14
# K_OA1  :  4
# K_OA2  :  8
# Y_A1  :  2
# Y_A2  :  13
# K_FA_AOBden  :  17
# K_FNA_AOBden  :  18
# K_IO_AOBden  :  22
# K_SNO_AOBden  :  24
# K_SO_AOBden  :  19
# n1_AOB  :  17
# n2_AOB  :  23
# K_A1  :  21
# K_F1  :  11
# K_O1_BH  :  12

# %%
#evaluate sensitivity
goat.Calc_sensitivity(np.array(results['.Aer_Anox_ZP.C(X_BA2)'].values).T)
#transform sensitivity into ranking
goat.Get_ranking() 

#plot the partial effect based sensitivity
fig, ax1 = goat.plotsens(indice='PE', ec='grey',fc='grey', outputid=10)
fig.set_size_inches(20, 10)
ax1.set_xticklabels(parasets.columns, rotation=90);
plt.savefig('X_BA2_ranking_10runs_10e_3pert.png', dpi=300, bbox_inches='tight')
# Out:
# Use PE_SENS for ranking purposes; since it uses the absolute value of the change; giving no compensation between positive and negative partial effects
# Combined ranking, by taking minimum ranking of the parameters over the different outputs
# K_O_A1Lysis  :  12
# K_O_A2Lysis  :  6
# b_A1  :  3
# b_A2  :  1
# n_NOx_A1_d  :  9
# K_FA  :  10
# K_FNA  :  4
# K_I10FA  :  15
# K_I10FNA  :  16
# K_I9FA  :  11
# K_I9FNA  :  17
# K_OA1  :  5
# K_OA2  :  2
# Y_A1  :  7
# Y_A2  :  8
# K_FA_AOBden  :  18
# K_FNA_AOBden  :  21
# K_IO_AOBden  :  23
# K_SNO_AOBden  :  24
# K_SO_AOBden  :  22
# n1_AOB  :  18
# n2_AOB  :  24
# K_A1  :  18
# K_F1  :  13
# K_O1_BH  :  14

# %%
#evaluate sensitivity
goat.Calc_sensitivity(np.array(results['.Aer_Anox_ZP.C(X_H)']).T)
#transform sensitivity into ranking
goat.Get_ranking() 

#plot the partial effect based sensitivity
fig, ax1 = goat.plotsens(indice='PE', ec='grey',fc='grey', outputid=10)
fig.set_size_inches(20, 10)
ax1.set_xticklabels(parasets.columns, rotation=90);
plt.savefig('X_H_ranking_10runs_10e_3pert.png', dpi=300, bbox_inches='tight')
# Out:
# Use PE_SENS for ranking purposes; since it uses the absolute value of the change; giving no compensation between positive and negative partial effects
# Combined ranking, by taking minimum ranking of the parameters over the different outputs
# K_O_A1Lysis  :  11
# K_O_A2Lysis  :  13
# b_A1  :  3
# b_A2  :  7
# n_NOx_A1_d  :  8
# K_FA  :  10
# K_FNA  :  9
# K_I10FA  :  17
# K_I10FNA  :  18
# K_I9FA  :  15
# K_I9FNA  :  15
# K_OA1  :  5
# K_OA2  :  4
# Y_A1  :  6
# Y_A2  :  14
# K_FA_AOBden  :  19
# K_FNA_AOBden  :  20
# K_IO_AOBden  :  21
# K_SNO_AOBden  :  24
# K_SO_AOBden  :  21
# n1_AOB  :  19
# n2_AOB  :  25
# K_A1  :  12
# K_F1  :  1
# K_O1_BH  :  2

# %%
#evaluate sensitivity
goat.Calc_sensitivity(np.array(results['.Aer_Anox_ZP.C(X_TSS)'].values).T)
#transform sensitivity into ranking
goat.Get_ranking() 

#plot the partial effect based sensitivity
fig, ax1 = goat.plotsens(indice='PE', ec='grey',fc='grey', outputid=10)
fig.set_size_inches(20, 10)
ax1.set_xticklabels(parasets.columns, rotation=90);
plt.savefig('TSS_ranking_10runs_10e_3pert.png', dpi=300, bbox_inches='tight')
# Out:
# Use PE_SENS for ranking purposes; since it uses the absolute value of the change; giving no compensation between positive and negative partial effects
# Combined ranking, by taking minimum ranking of the parameters over the different outputs
# K_O_A1Lysis  :  12
# K_O_A2Lysis  :  14
# b_A1  :  1
# b_A2  :  4
# n_NOx_A1_d  :  7
# K_FA  :  12
# K_FNA  :  9
# K_I10FA  :  15
# K_I10FNA  :  15
# K_I9FA  :  10
# K_I9FNA  :  16
# K_OA1  :  4
# K_OA2  :  3
# Y_A1  :  2
# Y_A2  :  9
# K_FA_AOBden  :  17
# K_FNA_AOBden  :  17
# K_IO_AOBden  :  18
# K_SNO_AOBden  :  19
# K_SO_AOBden  :  16
# n1_AOB  :  16
# n2_AOB  :  22
# K_A1  :  17
# K_F1  :  4
# K_O1_BH  :  7

# %%
goat.PE
# Out:
# array([[ 0.32142507,  0.32142507,  0.32142507, ...,  0.32144263,
#          0.32144263,  0.32144263],
#        [ 0.        ,  0.32142507,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 2.57139643,  2.24997549,  2.57140469, ...,  2.57154521,
#          2.57154521,  2.57154521],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.89183735,  1.89183735,  1.89183735, ...,  1.89183735,
#          1.89183735,  1.89183735],
#        [ 0.63061245,  0.63061245,  0.63061245, ...,  0.63061245,
#          0.63061245,  0.63061245]])

# %%
fig, ax1 = plt.subplots(figsize=(25, 10))
sns.heatmap(goat.PE, ax=ax1, annot=True, linewidths=.5, cmap="YlGnBu")

# ax1.xaxis.set_major_locator(plt.MaxNLocator(nbins=13))
# ax1.set_xticklabels(goat.PE.columns.tolist());

# %%
#plot the rankmatrix
fig, ax = goat.plot_rankmatrix(columns)
# fig.set_size_inches(18.5, 10.5)

# %%
results, units = reshape_files(case_dir,
                               'Eindhoven', 'Steady State', goat.parset2run.shape[0]) # or Dynamic!

# %%
#evaluate sensitivity
goat.Calc_sensitivity(np.array(results['.Aer_Anox_ZP.C(S_N2O)'].values).T)
#transform sensitivity into ranking
goat.Get_ranking() 

#plot the partial effect based sensitivity
fig, ax1 = goat.plotsens(indice='PE', ec='grey',fc='grey', outputid=10)
fig.set_size_inches(20, 10)
ax1.set_xticklabels(parasets.columns, rotation=90);
# plt.savefig('n2o_ranking_10runs_10e_6pert.png', dpi=300, bbox_inches='tight')
# Out:
# Use PE_SENS for ranking purposes; since it uses the absolute value of the change; giving no compensation between positive and negative partial effects
# Combined ranking, by taking minimum ranking of the parameters over the different outputs
# K_O_A1Lysis  :  13
# K_O_A2Lysis  :  10
# b_A1  :  6
# b_A2  :  3
# n_NOx_A1_d  :  11
# K_FA  :  7
# K_FNA  :  2
# K_I10FA  :  14
# K_I10FNA  :  15
# K_I9FA  :  14
# K_I9FNA  :  14
# K_OA1  :  8
# K_OA2  :  1
# Y_A1  :  9
# Y_A2  :  8
# K_FA_AOBden  :  15
# K_FNA_AOBden  :  16
# K_IO_AOBden  :  15
# K_SNO_AOBden  :  18
# K_SO_AOBden  :  16
# n1_AOB  :  14
# n2_AOB  :  15
# K_A1  :  14
# K_F1  :  4
# K_O1_BH  :  5
# ValueErrorTraceback (most recent call last)
# <ipython-input-21-3b1716088caf> in <module>()
#       5
#       6 #plot the partial effect based sensitivity
# ----> 7 fig, ax1 = goat.plotsens(indice='PE', ec='grey',fc='grey', outputid=10)
#       8 fig.set_size_inches(20, 10)
#       9 ax1.set_xticklabels(parasets.columns, rotation=90);
#
# /home/data/gbelland/.conda/envs/py2West/lib/python2.7/site-packages/pystran-0.1-py2.7.egg/pystran/sensitivity_globaloat.pyc in plotsens(self, indice, width, addval, sortit, outputid, *args, **kwargs)
#     461         ax1 = fig.add_subplot(111)
#     462         ax1 = plothbar(ax1, indtoplot, self._namelist, width = width,
# --> 463                       addval = addval, sortit = True, *args, **kwargs)
#     464         ax1.set_ylabel(indice,fontsize=20)
#     465         ax1.yaxis.label.set_rotation('horizontal')
#
# /home/data/gbelland/.conda/envs/py2West/lib/python2.7/site-packages/pystran-0.1-py2.7.egg/pystran/plot_functions_rev.pyc in plothbar(ax1, values, names, width, addval, sortit, *args, **kwargs)
#    1480                                          "< 0.001", color='0.5', size=10,
#    1481                                          horizontalalignment='left',
# -> 1482                                          verticalalignment='right')
#    1483                 else:
#    1484                     ax1.text(values[i]-0.025*np.abs(values).max(), ylocations[i]+bwidth/2.,
#
# /home/data/gbelland/.conda/envs/py2West/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in text(self, x, y, s, fontdict, withdash, **kwargs)
#     640         if fontdict is not None:
#     641             t.update(fontdict)
# --> 642         t.update(kwargs)
#     643
#     644         t.set_clip_path(self.patch)
#
# /home/data/gbelland/.conda/envs/py2West/lib/python2.7/site-packages/matplotlib/text.pyc in update(self, kwargs)
#     241         """
#     242         bbox = kwargs.pop('bbox', None)
# --> 243         super(Text, self).update(kwargs)
#     244         if bbox:
#     245             self.set_bbox(bbox)  # depends on font properties
#
# /home/data/gbelland/.conda/envs/py2West/lib/python2.7/site-packages/matplotlib/artist.pyc in update(self, props)
#     883         try:
#     884             ret = [_update_property(self, k, v)
# --> 885                    for k, v in props.items()]
#     886         finally:
#     887             self.eventson = store
#
# /home/data/gbelland/.conda/envs/py2West/lib/python2.7/site-packages/matplotlib/artist.pyc in _update_property(self, k, v)
#     877                 if func is None or not six.callable(func):
#     878                     raise AttributeError('Unknown property %s' % k)
# --> 879                 return func(v)
#     880
#     881         store = self.eventson
#
# /home/data/gbelland/.conda/envs/py2West/lib/python2.7/site-packages/matplotlib/text.pyc in set_verticalalignment(self, align)
#    1197         if align not in legal:
#    1198             raise ValueError('Vertical alignment must be one of %s' %
# -> 1199                              str(legal))
#    1200
#    1201         self._verticalalignment = align
#
# ValueError: Vertical alignment must be one of (u'top', u'bottom', u'center', u'baseline')
